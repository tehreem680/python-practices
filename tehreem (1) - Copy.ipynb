# %%
x = "hello world"
#display x:
print(x)
#display the data type of x:
print (type(x))





''
# Out:
# hello world
# <class 'str'>
# ''

# %%
x= 20
#display x:
#dispaly the data type of x:
print (type(x))
# Out:
# <class 'int'>

# %%
x = 20.5
#display x:
#display the data type of x:
print (type(x))
# Out:
# <class 'float'>

# %%
x = 1j
#display x:
#display the type of x:
print (type(x))
# Out:
# <class 'complex'>

# %%
x = ["apple , banana , cherry"]
#display x:
print(x)
#display the data type of x:
print (type(x))
# Out:
# ['apple , banana , cherry']
# <class 'list'>

# %%
x = ("apple" , "banana" , "cherry")
#display x:
print (x)
#display the data type of x:
print (type(x))
# Out:
# ('apple', 'banana', 'cherry')
# <class 'tuple'>

# %%
x = range (6)
#didplay x:
print (x)
#display the data type of x:
print (type(x))
# Out:
# range(0, 6)
# <class 'range'>
