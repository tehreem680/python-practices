# %%
x = 2
y = 4
print(x ** y) #same as 2*2*2*2
# Out:
# 16

# %%
a = 33
b = 200
if b > a:
  print("b is greater than a")
# Out:
# b is greater than a

# %%
a = 200
b =33
if b > a:
    print("b is greater than a")
elif a == b:
    print("a and b are equal")
else:
    print("b is greater than a")
# Out:
# b is greater than a

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")
else:
  print ("b is not gre ater than a")
# Out:
# b is not gre ater than a

# %%
a = 2
b = 330
print("A") if a>b else print("B")
# Out:
# B

# %%
 a = 200
 b = 33
 c = 500
 if a > b and c > a:
  print ("Both Conditions are True")
# Out:
# Both Conditions are True

# %%
 a= 200
 b = 33
 c = 500
 if a > b or a > c:
  print ("at least one of the condition is true")
# Out:
# at least one of the condition is true

# %%
a = 33
b = 200
if not a > b:
  print ("a is not greater than a")
# Out:
# a is not greater than a

# %%
a = 34
b = 87
if a > b:
  print (" a is greater than b")
else:
  print ("b is greater than a")
# Out:
# b is greater than a
